# %%
import os
from google.colab import drive

# 1. 挂载 Google Drive
drive.mount('/content/drive', force_remount=True)

# 2. 【关键修正】使用截图中的正确路径进行解压
# 路径是 /content/drive/MyDrive/minbert-default-final-project.zip
print("正在从 MyDrive 根目录解压文件...")
# !unzip -o -q "/content/drive/MyDrive/minbert-default-final-project.zip" -d /content/project_folder

# 3. 进入解压后的代码目录
# %cd /content/project_folder/minbert-default-final-project

# 4. 再次确认文件存在
print("\n当前目录文件：")
# !ls
# Out:
# Mounted at /content/drive
# 正在从 MyDrive 根目录解压文件...
# /content/project_folder/minbert-default-final-project
#
# 当前目录文件：
# base_bert.py	   datasets.py		    optimizer_test.py  sanity_check.py
# bert_base_uncased  evaluation.py	    predictions        setup.sh
# bert.py		   LICENSE		    prepare_submit.py  tokenizer.py
# classifier.py	   multitask_classifier.py  __pycache__        utils.py
# config.py	   optimizer.py		    README.md
# data		   optimizer_test.npy	    sanity_check.data

# %%
# !python3 classifier.py --option pretrain --lr 1e-3 --use_gpu
# Out:
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# Downloading: 100% 232k/232k [00:00<00:00, 18.0MB/s]
# Downloading: 100% 570/570 [00:00<00:00, 2.95MB/s]
# Downloading: 100% 440M/440M [00:04<00:00, 93.6MB/s]
# train-0: 100% 1068/1068 [00:23<00:00, 45.26it/s]
# eval: 100% 1068/1068 [00:23<00:00, 45.92it/s]
# eval: 100% 138/138 [00:02<00:00, 48.00it/s]
# save the model to sst-classifier.pt
# Epoch 0: train loss :: 1.585, train acc :: 0.350, dev acc :: 0.339
# train-1: 100% 1068/1068 [00:24<00:00, 44.42it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.74it/s]
# eval: 100% 138/138 [00:03<00:00, 45.17it/s]
# save the model to sst-classifier.pt
# Epoch 1: train loss :: 1.532, train acc :: 0.397, dev acc :: 0.389
# train-2: 100% 1068/1068 [00:24<00:00, 43.25it/s]
# eval: 100% 1068/1068 [00:24<00:00, 44.06it/s]
# eval: 100% 138/138 [00:02<00:00, 46.39it/s]
# ...

# %%
# !python3 classifier.py --option finetune --lr 1e-5 --use_gpu
# Out:
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# train-0: 100% 1068/1068 [01:52<00:00,  9.50it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.08it/s]
# eval: 100% 138/138 [00:03<00:00, 45.55it/s]
# save the model to sst-classifier.pt
# Epoch 0: train loss :: 1.240, train acc :: 0.587, dev acc :: 0.485
# train-1: 100% 1068/1068 [01:54<00:00,  9.34it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.29it/s]
# eval: 100% 138/138 [00:03<00:00, 43.91it/s]
# save the model to sst-classifier.pt
# Epoch 1: train loss :: 0.958, train acc :: 0.726, dev acc :: 0.506
# train-2: 100% 1068/1068 [01:54<00:00,  9.32it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.02it/s]
# eval: 100% 138/138 [00:03<00:00, 45.49it/s]
# save the model to sst-classifier.pt
# Epoch 2: train loss :: 0.756, train acc :: 0.843, dev acc :: 0.511
# train-3: 100% 1068/1068 [01:54<00:00,  9.34it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.35it/s]
# ...
